# %% [markdown]
# <a href="https://colab.research.google.com/github/EgorKulishov/sirius.ai/blob/main/fall_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Распознавание падения на изображении

# %% [markdown]
# # Установка библиотек

# %%
# установка библиотеки roboflow
pip install roboflow

# %% [markdown]
# # Импорт библиотек

# %%
from google.colab import files # библиотека для загрузки файлов с пк
from roboflow import Roboflow # библиотека для импорта модели с Roboflow
import cv2 # библиотека для работы с изображениями
from google.colab.patches import cv2_imshow # библиотека для вывода изображения в Google Colab

# %% [markdown]
# # Загрузка изображений

# %%
# загрузка изображения с пк
files.upload()

# %% [markdown]
# # Импорт модели

# %%
# импотр модели с roboflow
rf = Roboflow(api_key="jqnLmqWdCNIhvGjaFlAu")
project = rf.workspace().project("sirius.ai")
model = project.version(1).model

# %% [markdown]
# # Обработка падения

# %%
# вместо your_image.jpg надо ввести название загруженного изображения
image = "your_image.jpg"
# сохранение обработанного изображения
model.predict(image, confidence=40, overlap=30).save("prediction.jpg")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # Отображение изображения

# %%
# отображение обработанного изображения
img = cv2.imread("prediction.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=195x130>
